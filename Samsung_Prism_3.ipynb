# %%
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install datasets
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, GenerationConfig

# %%
from datasets import load_dataset

# %%
hugging_face_dataset_name = "knkarthick/dialogsum"
dataset = load_dataset(hugging_face_dataset_name)
# Out:
# ...
# Generating test split:   0%|          | 0/1500 [00:00<?, ? examples/s]

# %%
model_name = 'google/flan-t5-base'
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name,usefast =True)
# Out:
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d48d03506017> in <cell line: 1>()
# ----> 1 dataset.head()
#
# AttributeError: 'DatasetDict' object has no attribute 'head'

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'dialogue', 'summary', 'topic'],
#         num_rows: 12460
#     })
#     validation: Dataset({
#         features: ['id', 'dialogue', 'summary', 'topic'],
#         num_rows: 500
#     })
#     test: Dataset({
#         features: ['id', 'dialogue', 'summary', 'topic'],
#         num_rows: 1500
#     })
# })

# %%
print(type(dataset))
# Out:
# <class 'datasets.dataset_dict.DatasetDict'>

# %%
print(dataset['features'][0]['dialogue'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-7c097e4ade70> in <cell line: 1>()
# ----> 1 print(dataset['features'][0]['dialogue'])
#
# /usr/local/lib/python3.10/dist-packages/datasets/dataset_dict.py in __getitem__(self, k)
#      73     def __getitem__(self, k) -> Dataset:
#      74         if isinstance(k, (str, NamedSplit)) or len(self) == 0:
# ---> 75             return super().__getitem__(k)
#      76         else:
#      77             available_suggested_splits = [
#
# KeyError: 'features'

# %%
from transformers import pipeline

qa_model = pipeline("question-answering")
question = "Where do I live?"
context = "My name is Merve and I live in İstanbul."
qa_model(question = question, context = context)
## {'answer': 'İstanbul', 'end': 39, 'score': 0.953, 'start': 31}
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# ...

# %%
qa_model = pipeline("question-answering")
question = "for how many hours refrigerator was opened"
context = "I opened refrigerator at 5pm and closed it on 8pm"
qa_model(question = question, context = context)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# {'score': 0.4184536933898926, 'start': 46, 'end': 49, 'answer': '8pm'}

# %%
qa_model = pipeline("question-answering")

# Example
example_question = "For how many hours was the refrigerator opened yesterday?"
example_context = "I opened the refrigerator at 7am and closed it at 10am."
example_answer = qa_model(question=example_question, context=example_context)
print(f"Example Answer: {example_answer['answer']}")

# Actual question
question = "For how many hours was the refrigerator opened?"
context = "I opened the refrigerator at 5pm and closed it at 8pm."
answer = qa_model(question=question, context=context)
print(answer)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Example Answer: 7am and closed it at 10am
# {'score': 0.27973124384880066, 'start': 29, 'end': 53, 'answer': '5pm and closed it at 8pm'}

# %%
qa_model = pipeline("question-answering")

# Example 1
example1_question = "For how many hours was the refrigerator opened yesterday?"
example1_context = "I opened the refrigerator at 7am and closed it at 10am."
example1_answer = qa_model(question=example1_question, context=example1_context)
print(f"Example 1 Answer: {example1_answer['answer']}")

# Example 2
example2_question = "How long was the door left open?"
example2_context = "The door was opened at 12pm and closed at 3pm."
example2_answer = qa_model(question=example2_question, context=example2_context)
print(f"Example 2 Answer: {example2_answer['answer']}")

# Actual question
question = "For how many hours was the refrigerator opened?"
context = "I opened the refrigerator at 5pm and closed it at 8pm."
answer = qa_model(question=question, context=context)
print(answer)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Example 1 Answer: 7am and closed it at 10am
# Example 2 Answer: 12pm
# {'score': 0.27973124384880066, 'start': 29, 'end': 53, 'answer': '5pm and closed it at 8pm'}

# %%
import json

# %%
data = [
    {"prompt": "What was the last time the living room lights were turned on?", "response": "The living room lights were turned on at 6:30 PM."},
    {"prompt": "What is the current temperature reported by the greenhouse sensor?", "response": "The current temperature in the greenhouse is 22°C."},
    {"prompt": "Is the front door currently locked or unlocked?", "response": "The front door is currently locked."},
    {"prompt": "How much energy did the washing machine consume during its last cycle?", "response": "The washing machine consumed 1.2 kWh during the last cycle."},
    {"prompt": "When was the last motion detected in the garage?", "response": "Motion was last detected in the garage at 10:15 PM."}
]

with open('iot_dataset.json', 'w') as f:
    json.dump(data, f)

# %%
pip install datasets

# %%
# !pip uninstall -y datasets
# !pip install datasets
# Out:
# Found existing installation: datasets 2.21.0
# Uninstalling datasets-2.21.0:
#   Successfully uninstalled datasets-2.21.0
# ...
#   Using cached datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# ...
# Using cached datasets-2.21.0-py3-none-any.whl (527 kB)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-39fecb511475> in <cell line: 1>()
# ----> 1 datasets
#
# NameError: name 'datasets' is not defined
